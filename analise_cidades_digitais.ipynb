# %% [markdown]
# # Análise exploratória cidades digitais

# %% [markdown]
# ## Fonte de dados:
# > [Cidades Digitais](https://dados.gov.br/dataset/cidades-digitais)

# %% [markdown]
# ## Introdução
# Análise exploratória do dataframe e entendimento dos dados

# %% [markdown]
# ## Importação e carga dos dados

# %%
import numpy as np
import pandas as pd

# %%
dados = pd.read_csv('cidades_digitais.csv', sep=';', encoding='latin-1')

# %% [markdown]
# ## Primeiras visualizações

# %% [markdown]
# ### Primeiros Registros

# %%
dados.head()
# Out:
#    UF              CIDADE     IBGE  POPULAÇÃO VALOR_TOTAL_PREVISTO  \
# 0  AC            Tarauacá  1200609      38819           484.547,53
# 1  AL     Delmiro Gouveia  2702405      51997         1.169.381,70
# 2  AL  Estrela de Alagoas  2702553      18306           527.206,83
# 3  AM             Autazes  1300300      37033         1.171.151,92
# 4  AM   Benjamin Constant  1300607      39484           844.586,48
#
#          STATUS  PONTOS_ATENDIDOS VALOR_INVESTIDO
# 0  Sem Previsão                 8               0
# 1  Sem Previsão                43               0
# 2  Sem Previsão                39               0
# 3  Sem Previsão                51               0
# 4  Sem Previsão                12               0

# %% [markdown]
# ### Últimos registros

# %%
dados.tail()
# Out:
#      UF                   CIDADE     IBGE  POPULAÇÃO VALOR_TOTAL_PREVISTO  \
# 333  SP     Vargem Grande do Sul  3556404      41807         1.525.640,54
# 334  TO     Paraíso do Tocantins  1716109      49076         1.872.693,90
# 335  TO  Ponte Alta do Bom Jesus  1717800       4649           251.266,44
# 336  TO           Porto Nacional  1718204      52182         1.101.168,76
# 337  TO  São Miguel do Tocantins  1720200      11597           592.549,70
#
#            STATUS  PONTOS_ATENDIDOS VALOR_INVESTIDO
# 333  Sem Previsão                47               0
# 334  Sem Previsão                49               0
# 335  Sem Previsão                 9       23.969,90
# 336  Sem Previsão                61               0
# 337  Sem Previsão                20               0

# %% [markdown]
# ### Números de linhas e colunas

# %%
dados.shape
# Out:
# (338, 8)

# %% [markdown]
# ### Nome das variáveis observáveis

# %%
list(dados.columns)
# Out:
# ['UF',
#  'CIDADE',
#  'IBGE',
#  'POPULAÇÃO',
#  'VALOR_TOTAL_PREVISTO',
#  'STATUS',
#  'PONTOS_ATENDIDOS',
#  'VALOR_INVESTIDO']

# %% [markdown]
# ### Tipo de dados por coluna

# %%
dados.dtypes
# Out:
# UF                      object
# CIDADE                  object
# IBGE                     int64
# POPULAÇÃO                int64
# VALOR_TOTAL_PREVISTO    object
# STATUS                  object
# PONTOS_ATENDIDOS         int64
# VALOR_INVESTIDO         object
# dtype: object

# %% [markdown]
# ## Tendencias de centralidade

# %%
dados.describe(include='all')
# Out:
#          UF    CIDADE          IBGE      POPULAÇÃO VALOR_TOTAL_PREVISTO  \
# count   338       338  3.380000e+02     338.000000                  338
# unique   27       338           NaN            NaN                  331
# top      SP  Japonvar           NaN            NaN           674.932,84
# freq     35         1           NaN            NaN                    2
# mean    NaN       NaN  2.860567e+06   32202.497041                  NaN
# std     NaN       NaN  9.658648e+05   36054.136101                  NaN
# min     NaN       NaN  1.100106e+06    2249.000000                  NaN
# 25%     NaN       NaN  2.206854e+06   14991.500000                  NaN
# 50%     NaN       NaN  2.805505e+06   25129.000000                  NaN
# 75%     NaN       NaN  3.506588e+06   38931.500000                  NaN
# max     NaN       NaN  5.300108e+06  343230.000000                  NaN
#
#               STATUS  PONTOS_ATENDIDOS VALOR_INVESTIDO
# count            338        338.000000             338
# unique             3               NaN             100
# top     Sem Previsão               NaN               0
# freq             258               NaN             238
# mean             NaN         22.494083             NaN
# std              NaN          9.881867             NaN
# min              NaN          5.000000             NaN
# 25%              NaN         15.000000             NaN
# 50%              NaN         21.000000             NaN
# 75%              NaN         27.000000             NaN
# max              NaN         61.000000             NaN

# %% [markdown]
# ### Tipos de STATUS

# %%
set(dados['STATUS'])
# Out:
# {'Concluída', 'Em andamento', 'Sem Previsão'}

# %% [markdown]
# ## Distribuição de cidades por UF

# %% [markdown]
# ###   Os dez estados com mais cidades atendidas

# %%
grupos_uf = dados.groupby(['UF'])
grupos_uf.size().sort_values(ascending=False)[0:10]
# Out:
# UF
# SP    35
# BA    33
# MG    28
# MA    26
# CE    26
# PA    24
# PI    18
# PB    18
# PR    17
# PE    16
# dtype: int64

# %% [markdown]
# ### Os dez estados com a menor quantidade de cidades atendidas pelo programa

# %%
grupos_uf.size().sort_values(ascending=True)[0:10]
# Out:
# UF
# AC    1
# RR    1
# DF    1
# AL    2
# RO    2
# MS    3
# SE    4
# MT    4
# TO    4
# ES    4
# dtype: int64

# %% [markdown]
# ## Visualizar os dados por UF e STATUS

# %%
df = dados.set_index(['UF','STATUS'])

# %%
df.groupby(level=['UF', 'STATUS'])

# %%
df
# Out:
#                                   CIDADE     IBGE  POPULAÇÃO  \
# UF STATUS
# AC Sem Previsão                 Tarauacá  1200609      38819
# AL Sem Previsão          Delmiro Gouveia  2702405      51997
#    Sem Previsão       Estrela de Alagoas  2702553      18306
# AM Sem Previsão                  Autazes  1300300      37033
#    Sem Previsão        Benjamin Constant  1300607      39484
#    Sem Previsão                  Careiro  1301100      36435
#    Concluída                       Coari  1301209      83078
#    Sem Previsão                  Codajás  1301308      26777
#    Sem Previsão                 Iranduba  1301852      45984
#    Concluída                  Manacapuru  1302504      94175
#    Concluída                   Manaquiri  1302553      28413
#    Sem Previsão                    Maraã  1302801      18423
# AP Sem Previsão                    Amapá  1600105       8622
#    Sem Previsão         Laranjal do Jari  1600279      45712
#    Sem Previsão                  Mazagão  1600402      19571
#    Sem Previsão             Porto Grande  1600535      19669
#    Concluída              Serra do Navio  1600055       4938
#    Sem Previsão          Vitória do Jari  1600808      14364
# BA Sem Previsão                    Abaré  2900207      19574
#    Sem Previsão                    Anagé  2901205      20096
#    Sem Previsão                  Anguera  2901502      11299
#    Sem Previsão              Baianópolis  2902500      14195
#    Sem Previsão                    Barra  2902708      54188
#    Sem Previsão           Barra do Choça  2902906      34853
#    Sem Previsão       Boa Vista do Tupim  2903805      18658
#    Sem Previsão       Bom Jesus da Serra  2903953      10554
#    Sem Previsão              Brejolândia  2904407      10698
#    Sem Previsão               Buritirama  2904753      21549
#    Sem Previsão          Coronel João Sá  2909208      17098
#    Sem Previsão                 Cotegipe  2909406      14403
# ...                                  ...      ...        ...
# SP Concluída                  Guararapes  3518206      32346
#    Sem Previsão                   Guareí  3518503      16867
#    Sem Previsão                    Ibaté  3519303      33535
#    Sem Previsão                Ituverava  3524105      40994
#    Sem Previsão                    Jales  3524808      48922
#    Sem Previsão                   Jarinu  3525201      27473
#    Concluída                     Lourdes  3527256       2249
#    Sem Previsão                 Louveira  3527306      43862
#    Sem Previsão                Mairinque  3528403      46015
#    Sem Previsão                 Miracatu  3529906      20533
#    Sem Previsão  Mirante do Paranapanema  3530201      17979
#    Sem Previsão                 Orlândia  3534302      42678
#    Sem Previsão              Pederneiras  3536703      44910
#    Concluída                   Penápolis  3537305      62071
