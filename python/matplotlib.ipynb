# %% [markdown]
# # Matplotlib - Exercícios

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
x = np.linspace(0,5,11)

# %%
y = x **2

# %%
# usando como programação sequencial
plt.plot(x,y,'r--')
plt.xlabel('Escala de X')
plt.ylabel('Escala Y')
plt.title('Titulo')
# Out:
# Text(0.5,1,'Titulo')

# %% [markdown]
# ### Multiplos graficos com subplot
# Essa função cria uma matriz de plots, recebe a linha, coluna e qual grafico que será usado

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'b--')
plt.subplot(1,2,2)
plt.plot(y,x,'r--')

# %% [markdown]
# ### Criando um figure manualmente

# %%
# figure cria uma tela de desenho para os gráficos
# add_axes recebe margem esquerda, baixo, largura e altura
fig = plt.figure()
axes = fig.add_axes([0.1,0.1,0.9,0.9])
axes.plot(x,y)
axes.set_xlabel('Eixo X')
axes.set_ylabel('Eixo Y')
axes.set_title('Gráfico 1')

axes2 = fig.add_axes([0.15,0.5,0.5,0.3])
axes2.plot(x,y)
axes2.set_xlabel('Eixo X')
axes2.set_ylabel('Eixo Y')
axes2.set_title('Gráfico 2')
# Out:
# Text(0.5,1,'Gráfico 2')

# %% [markdown]
# ### Usando subplots
# retorna um figure e uma lista de eixos

# %%
fig, axes = plt.subplots(1,2)

# %%
axes[0].plot(x,y)
axes[1].plot(y,x)
fig

# %%
#salva a imagem
fig.savefig('teste.jpg')

# %% [markdown]
# ## Exercícios

# %%
x= np.arange(0,100)
y = x*2
z = x**2

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y)

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,0.2,0.2])
